# %%
import numpy as np
import pandas as pd

from pyspark.ml.fpm import FPGrowth
from pyspark.sql import SparkSession
from pyspark import SparkConf, SparkContext

from sklearn.decomposition import NMF
from sklearn.metrics import mean_absolute_error

# %%
# orders = pd.read_csv("../../instacart_2017_05_01/orders.csv")


# order_ids_test = np.loadtxt("../../instacart_2017_05_01/order_ids_test.txt", dtype=np.int)
# order_ids_train = np.loadtxt("../../instacart_2017_05_01/order_ids_train.txt", dtype=np.int)

# orders_train = orders.loc[order_ids_train, :]
# orders_test = orders.loc[order_ids_test, :]

# %%
# filter user with more than 10 orders
orders = pd.read_csv("../../instacart_2017_05_01/orders.csv")
print(orders.shape)
orders = orders[orders.eval_set=="prior"]
user_freq = orders.user_id.value_counts()
user_freq = user_freq[user_freq>50]
orders = orders[orders.user_id.isin(user_freq.index)]
print(orders.shape)
# Out:
# (3421083, 7)
# (722360, 7)

# %%
# user profile
user_dows = orders[["order_dow", "user_id"]].groupby("user_id").agg(lambda x:x.value_counts().index[0])
user_profiles = orders[["order_hour_of_day", "days_since_prior_order", "user_id"]].groupby("user_id").mean()
user_profiles = user_profiles.merge(user_dows, left_index=True, right_index=True)
print(user_profiles.shape)
user_profiles.head()
# Out:
# (10328, 3)
#          order_hour_of_day  days_since_prior_order  order_dow
# user_id
# 27               12.469136                4.437500          2
# 50               11.253731                5.409091          1
# 54               12.844156                4.776316          4
# 90               12.126761                3.471429          5
# 140              13.986842                4.840000          6

# %%
# filter product with more than 10 purchases
order_products = pd.read_csv("../../instacart_2017_05_01/order_products__prior.csv")
order_products = order_products[["order_id", "product_id"]]
print(order_products.shape)
product_freq = order_products.product_id.value_counts()
product_freq = product_freq[product_freq>10]
order_products = order_products[order_products.product_id.isin(product_freq.index)]
order_products = order_products[order_products.order_id.isin(orders.order_id.unique())]
order_products = order_products.merge(orders[["order_id", "user_id"]])
print(order_products.shape)
order_products.head()
# Out:
# (32434489, 2)
# (7042185, 3)
#    order_id  product_id  user_id
# 0         4       46842   178520
# 1         4       26434   178520
# 2         4       39758   178520
# 3         4       27761   178520
# 4         4       10054   178520

# %%
# split train and test
order_ids = order_products.order_id.unique()
np.random.shuffle(order_ids)
order_ids_train = order_ids[0:int(order_ids.shape[0]*4/5)]
order_ids_test = order_ids[int(order_ids.shape[0]*4/5):]
np.savetxt("../../instacart_2017_05_01/order_ids_test.txt", order_ids_test, fmt="%d")
np.savetxt("../../instacart_2017_05_01/order_ids_train.txt", order_ids_train, fmt="%d")

# %%
# product profile
product_profiles = pd.read_csv("../../instacart_2017_05_01/products.csv")
print(product_profiles.shape)
product_profiles = product_profiles[product_profiles.product_id.isin(order_products.product_id.unique())]
print(product_profiles.shape)
product_profiles.head()
# Out:
# (49688, 4)
# (38061, 4)
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 6           7                     Pure Coconut Water With Orange        98
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 6              7

# %% [markdown]
# # FP Growth

# %%
spark = SparkSession.builder.master("local").appName("Search").config(conf=SparkConf()).getOrCreate()

# %%
order_product = order_products[["order_id", "product_id"]].groupby("order_id").agg(lambda x:x.tolist())

# %%
order_product_test = order_product[order_product.index.isin(order_ids_test)]
order_product_test["input"] = order_product_test.apply(lambda x:x[0][:int(len(x[0]) *2/3)], axis=1)
order_product_test["output"] = order_product_test.apply(lambda x:x[0][int(len(x[0]) *2/3):], axis=1)
order_product_test = order_product_test[["input", "output"]]
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
order_product_train = order_product[order_product.index.isin(order_ids_train)]
order_product_train.rename({"product_id":"input"}, axis=1, inplace=True)
order_product_test["id"] = order_product_test.index
order_product_train["id"] = order_product_train.index

# %%
train_sdf = spark.createDataFrame(order_product_train)
test_sdf = spark.createDataFrame(order_product_test)

# %%
fpGrowth = FPGrowth(itemsCol="input", minSupport=0.01, minConfidence=0.005)
model = fpGrowth.fit(train_sdf)

# %%
# Display frequent itemsets.
model.freqItemsets.show()

# Display generated association rules.
model.associationRules.show()
# Out:
# +-------+-----+
# |  items| freq|
# +-------+-----+
# |[41220]| 6453|
# |[38159]| 6148|
# |[27156]| 6868|
# |[29447]| 5783|
# |[27086]|14954|
# |[37687]| 6012|
# |[24489]| 6306|
# |[46906]| 7130|
# | [9387]| 6671|
# |[28985]|10837|
# |[43352]| 8952|
# |[34969]| 8266|
# |[39877]|13395|
# |[10749]|11751|
# |[38689]| 8823|
# |[43122]|10374|
# |[41950]|12690|
# |[26209]|23990|
# | [5876]|17890|
# |[22825]|11565|
# +-------+-----+
# only showing top 20 rows
#
# +----------+----------+-------------------+------------------+
# |antecedent|consequent|         confidence|              lift|
# +----------+----------+-------------------+------------------+
# |   [28204]|   [24852]| 0.4098731315161412| 2.823901695861819|
# |   [16797]|   [24852]|0.28518255937610776|1.9648214316304606|
# |   [24852]|   [16797]|0.07673872348543562|1.9648214316304606|
# |   [24852]|   [21137]|0.14309220331707784|1.3925366145768279|
# |   [24852]|   [21903]|0.10844292885333079|1.4486266521448545|
# |   [24852]|   [47766]|0.10388820660792426|2.2378352358124918|
# |   [24852]|   [47626]|0.07604716879896029|1.8858627372834136|
# |   [24852]|   [28204]|0.07781182558513873| 2.823901695861819|
# |   [24852]|   [47209]| 0.0769294971920495|0.9186832252769617|
# |   [24852]|   [27845]|0.09080828434820971|1.6150676401703565|
# |   [47626]|   [24852]| 0.2737221578473027|1.8858627372834136|
# |   [21903]|   [21137]| 0.1914185315331977|1.8628360433995337|
# |   [21903]|   [13176]| 0.2276678379877936|1.6073524608731475|
# |   [21903]|   [47209]|0.17049657850933975|2.0360505704674563|
# |   [21903]|   [24852]| 0.2102598483447383|1.4486266521448548|
# |   [19057]|   [13176]| 0.3305922880320036| 2.334007000771076|
# |   [27845]|   [21137]|0.18563206008187386| 1.806523587665544|
# |   [27845]|   [13176]| 0.1983440549108929|1.4003242951587889|
# |   [27845]|   [24852]|0.23441780294869033|1.6150676401703565|
# |   [13176]|   [21137]| 0.1789602297024864|1.7415950459688616|
# +----------+----------+-------------------+------------------+
# only showing top 20 rows

# %%
# transform examines the input items against all the association rules and summarize the
# consequents as prediction
test_pred = model.transform(test_sdf).select("*").toPandas()

# %%
test_pred
# Out:
#                                                     input  \
# 0       [46842, 26434, 39758, 27761, 10054, 21351, 225...
# 1        [43875, 27845, 47049, 8186, 34134, 42345, 28682]
# 2                                          [28745, 22124]
# 3                                                 [17794]
# 4               [4421, 18770, 24184, 13176, 42265, 16249]
# ...                                                   ...
# 144454  [35842, 35951, 27966, 11143, 26209, 42265, 126...
# 144455                                      [22372, 7625]
# 144456  [10603, 43858, 35958, 35425, 2732, 3793, 21137...
# 144457          [24561, 13113, 46906, 4799, 30949, 26790]
# 144458                               [44275, 2386, 12442]
#
#                                      output       id  \
# 0       [40285, 17616, 25146, 32645, 41276]        4
# 1              [36342, 12341, 11140, 23060]       69
# 2                             [26604, 5212]      104
# 3                                   [18644]      122
# 4               [28278, 7010, 41290, 39984]      128
# ...                                     ...      ...
# 144454   [15689, 9070, 27057, 47209, 43122]  3420991
# 144455                       [16131, 32295]  3420993
# 144456   [35547, 40063, 45081, 5322, 38730]  3421004
# 144457            [40706, 8518, 35108, 300]  3421006
# 144458                       [23835, 32691]  3421065
#
#                                               prediction
# 0                                                     []
# 1                                  [21137, 13176, 24852]
# 2                                                     []
# 3                                                     []
# 4       [21137, 27966, 8277, 21903, 19057, 47209, 27845]
# ...                                                  ...
# 144454                             [21137, 13176, 47209]
# 144455                                                []
# 144456        [13176, 24852, 27966, 21903, 47209, 27845]
# 144457                                                []
# 144458                                                []
#
# [144459 rows x 4 columns]

# %%
# order_product_test = order_product_test.merge(test_pred[["id", "prediction"]], left_on='id', right_on="id") 
test_pred["hit"] = test_pred.apply(lambda x:len(set(x["prediction"]).intersection(x["output"])), axis=1)
test_pred["total"] = test_pred.apply(lambda x:len(x["output"]), axis=1)

# %%
sum(test_pred["hit"])/sum(test_pred["total"])
# Out:
# 0.08469992234304334

# %% [markdown]
# # Negative Matrix Factorization

# %%
order_products_train = order_products[order_products.order_id.isin(order_ids_train)]
train = order_products_train.pivot_table(index="user_id", columns="product_id", aggfunc=len, fill_value=0)

# %%
test = order_products.pivot_table(index="user_id", columns="product_id", aggfunc=len, fill_value=0)

# %%
test = test[test.index.isin(train.index)]
test = test[train.columns]

# %%
train.shape
test.shape
# Out:
# (10328, 37398)

# %%
# Converting the ratings into binary ratings 1 (Liked) or 0 (Not Liked)
train[train == 0] = -1
train[train >= 1] = 1
test[test == 0] = -1
test[test >= 1] = 1

# %%
np.save("trian.npy", np.array(train))
np.save("test.npy", np.array(test))

# %%
train[train == -1] = 0
train[train >= 1] = 1
test[test == -1] = 0
test[test >= 1] = 1

# %%
nmf = NMF(n_components=3, 
         random_state=0,
         verbose=True)

user_distribution = nmf.fit_transform(train)
# violation: 0.00016489394690226978
# violation: 0.00016195189275755806
# violation: 0.0001590608348956663

# %%
print(mean_absolute_error(test, reconstruct_matrix))
print(mean_absolute_error(train, reconstruct_matrix))
print(mean_absolute_error(test, train))
# Out:
# 0.007851114130976096
# 0.007449875120477275
# 0.00046836665029163343

# %%
nmf = NMF(n_components=5, 
         random_state=0,
         verbose=True)

user_distribution = nmf.fit_transform(train)
item_distribution = nmf.components_

reconstruct_matrix = np.dot(user_distribution, item_distribution)
# Out:
# violation: 1.0
# violation: 0.4205794797462163
# violation: 0.309877636861129
# violation: 0.24607846527096727
# violation: 0.21267385783331663
# violation: 0.1882665843349099
# violation: 0.16859568331483146
# violation: 0.1514766174128897
# violation: 0.13628267426102528
# violation: 0.12240522756921024
# violation: 0.11025952639457028
# violation: 0.09918439753670596
# violation: 0.08928878487878253
# violation: 0.08033736426392275
# violation: 0.07195453196224152
# violation: 0.06435007530203904
# violation: 0.057311978019191114
# violation: 0.05092181523877545
# violation: 0.045158147333612265
# violation: 0.03990548138178395
# violation: 0.03506235219060173
# violation: 0.030724707102265394
# violation: 0.026883425474123132
# violation: 0.023446724513407433
# violation: 0.020428550116165647
# violation: 0.017754442015485476
# violation: 0.015415319108411407
# violation: 0.01336837905191067
# violation: 0.011590615476934385
# violation: 0.010061437956173548
# violation: 0.00873704440440301
# violation: 0.007610808920189908
# violation: 0.006637129373928012
# violation: 0.0057449583129065085
# violation: 0.0049767598193644486
# violation: 0.004310339085961782
# violation: 0.0037321361342098672
# violation: 0.003230599382141804
# violation: 0.0027968801425975803
# violation: 0.002421441658436866
# violation: 0.002097380415774714
# violation: 0.001817539940997129
# violation: 0.0015756980083293866
# violation: 0.0013663390200052568
# violation: 0.001185596459471637
# violation: 0.0010292376402028334
# violation: 0.0008941680482728439
# violation: 0.0007776252603451908
# violation: 0.000676933980641537
# violation: 0.0005899099231850781
# violation: 0.0005146687754139445
# violation: 0.0004488003762794218
# violation: 0.000392086432463046
# violation: 0.0003429958049425435
# violation: 0.00030041842347011563
# violation: 0.00026345688615430284
# violation: 0.00023136756413463664
# violation: 0.0002034364583635755
# violation: 0.00017910769489017464
# violation: 0.00015789572503478432
# violation: 0.00013942165221238445
# violation: 0.0001232863896193459
# violation: 0.00010918680377326638
# violation: 9.685066250380081e-05
# Converged at iteration 64

# %%
print(mean_absolute_error(test, reconstruct_matrix))
print(mean_absolute_error(train, reconstruct_matrix))
print(mean_absolute_error(test, train))
# Out:
# 0.005785982087505418
# 0.007389462159671093
# 0.00046836665029163343

# %%
nmf = NMF(n_components=10, 
         random_state=0,
         verbose=True)

user_distribution = nmf.fit_transform(train)
item_distribution = nmf.components_

reconstruct_matrix = np.dot(user_distribution, item_distribution)
# Out:
# violation: 1.0
# violation: 0.37149155997787797
# violation: 0.2992321929579902
# violation: 0.250459435270304
# violation: 0.20672044575889714
# violation: 0.17081398018282706
# violation: 0.001733384388091837
# violation: 0.0016796540195395961
# violation: 0.0016284734395268041
# violation: 0.001579473307038638
# violation: 0.0015318821227530066
# violation: 0.001486271755697668
# violation: 0.001442711447565239
# violation: 0.0014007265713917682
# violation: 0.001360302045419606
# violation: 0.001321336522164079
# violation: 0.0012834275890979572
# violation: 0.001246675971998624
# violation: 0.0012082872019111082
# violation: 0.0011721518220782629
# violation: 0.001137387116432491
# violation: 0.0011035848901837263
# violation: 0.001070470507877569
# violation: 0.001037966920537185
# violation: 0.0010063135865984183
# violation: 0.000975680193198305
# violation: 0.0009457766665775484
# violation: 0.0009168773596993749
# violation: 0.0008890196662132802
# violation: 0.0008597514574570694
# violation: 0.0008313502337094708
# violation: 0.0008047247739898446
# violation: 0.0007791797261359522
# violation: 0.000754580933567866
# violation: 0.0007308650406798782
# violation: 0.0007079216627260478
# violation: 0.000685885281937024
# violation: 0.0006648041635015501
# violation: 0.0006444311518385485
# violation: 0.0006247376063985418
# violation: 0.0006058422328491591
# violation: 0.000587626996959631
# violation: 0.0005700456123931011
# violation: 0.0005530589328803609
# violation: 0.0005364568750623047
# violation: 0.0005201321204224074
# violation: 0.0005046432801265096
# violation: 0.0004897792917470901
# violation: 0.0004755269572275175
# violation: 0.0004618400844894931
# violation: 0.0004486356250415638
# violation: 0.0004358938697200515
# violation: 0.000423577413357387
# violation: 0.0004116805893251738
# violation: 0.0004001716132646024
# violation: 0.00038904066059322623
# violation: 0.00037823713110891606
# violation: 0.0003677942560705659
# violation: 0.0003576898899508384
# violation: 0.0003479344474042655
# violation: 0.0003385047420975075
# violation: 0.0003294372557053082
# violation: 0.00032067147670100025
# violation: 0.00031216440451698114
# violation: 0.00030394486150480906
# violation: 0.00029598444939489787
# violation: 0.00028824968735821545
# violation: 0.0002807820375546157
# violation: 0.0002736088692241869
# violation: 0.0002666858597173164
# violation: 0.0002599783920463493
# violation: 0.0002534846818821036
# violation: 0.00024717955883047017
# violation: 0.00024106704115684958
# violation: 0.00023515578266288588
# violation: 0.00022945559182085577
# violation: 0.00022399017384381248
# violation: 0.0002187334590522116
# violation: 0.00021363370304272405
# violation: 0.00020868464441384848
# violation: 0.00020385625045441554
# violation: 0.0001991986627055576
# violation: 0.00019470122231371968
# violation: 0.0001903578420121291
# violation: 0.00018615415789730868
# violation: 0.00018208179585876754
# violation: 0.0001781082987715467
# violation: 0.00017427124229221078
# violation: 0.0001705359571079392
# violation: 0.00016690276488215492
# violation: 0.00016335617342006696
# violation: 0.0001599034929004716
# violation: 0.00015653880248048182
# violation: 0.00015326211697792974
# violation: 0.00015007173397739145
# violation: 0.00014695962264192478
# violation: 0.00014392704527021379

# %%
print(mean_absolute_error(test, reconstruct_matrix))
print(mean_absolute_error(train, reconstruct_matrix))
print(mean_absolute_error(test, train))
# Out:
# 0.007813905387676595
# 0.007422535762452923
# 0.00046836665029163343
